# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib

# %%
# Load our questionnaire data
data_file_path = "../questionnaire/questionnaire.csv"
df = pd.read_csv(data_file_path)

# %%
diff = df[df["Type"] == "Diff"]
questions_diff = diff.drop(["ID","Type","Age","Sex"], axis=1)
questions_diff = questions_diff.agg(["mean", "std"]).T

# %%
guess = df[df["Type"] == "Guess"]
questions_guess = guess.drop(["ID","Type","Age","Sex"], axis=1)
questions_guess = questions_guess.agg(["mean", "std"]).T
questions_guess
# Out:
#                                                       mean       std
# I have previous experience with electric vehicles   2.5625  1.824600
# I have previous experience with being in Virtua...  2.9375  1.730848
# It was easy to drive the entire distance withou...  3.9375  1.878608
# I was sure from the beginning, that I would rea...  3.7500  1.914854
# How sure I was about reaching the destination, ...  4.2500  1.983263
# I found the dashboard to be reliable\n              5.1875  1.327592
# I found the dashboard useful for completing the...  5.8750  1.024695
# The displayed remaining distance agreed with th...  5.1875  1.600781
# I felt I understood what affected the remaining...  5.4375  1.412740
# I felt I could influence the displayed remainin...  5.6875  1.400893
# The dashboard was difficult to understand\n         1.8125  0.910586
# I felt the dashboard lacked information for com...  3.2500  1.693123

# %% [markdown]
# We want bars for each question asked with the mean value + std

# %%
# Plot window presets & color constants
plt.style.use("default")
params = {
    'font.size': 12,
    'axes.labelsize': 15,
    'axes.titlesize': 15,
    'legend.fontsize': 12,
    'xtick.labelsize': 15,
    'ytick.labelsize': 15
}
matplotlib.rcParams.update(params)

color_road = "k"
color_diff = "#FFA85C"
color_diff_border = "#E06900"
color_diff_a1 = "#1B998B"
color_guess = "#3F9CDE"
color_guess_a1 = "#1B998B"
color_guess_border = "#1B679D"

# %%
# Plot the data in a bar chart diagram

fig, ax = plt.subplots(figsize=(15,8))

labels = questions_guess.index
guess_mean = questions_guess["mean"].values
guess_std = questions_guess["std"].values

labels = questions_guess.index
diff_mean = questions_diff["mean"].values
diff_std = questions_diff["std"].values

x = np.arange(len(labels))
width = 0.4
capsize = 3

ax.bar(x - width/2, guess_mean, width, yerr=guess_std, capsize=capsize, label="Guess-o-meter", color=color_guess)
ax.bar(x + width/2, diff_mean, width, yerr=diff_std , capsize=capsize, label="Diff+COPE1", color=color_diff)

ax.set_xlabel("Question id")
ax.set_ylabel("Mean score [0=Not at all, 7=Extremely]")
ax.set_title("Questionnaire mean score")

ax.set_ylim(0,7)
ax.grid(True)
ax.legend()
ax.set_xticks(x);
ax.set_xticklabels(labels, rotation=90)
# Out:
# [Text(0, 0, 'I have previous experience with electric vehicles'),
#  Text(0, 0, 'I have previous experience with being in Virtual Reality'),
#  Text(0, 0, 'It was easy to drive the entire distance without running out of battery\n'),
#  Text(0, 0, 'I was sure from the beginning, that I would reach the destination without running out of battery\n'),
#  Text(0, 0, 'How sure I was about reaching the destination, without running out of battery, changed throughout the drive\n'),
#  Text(0, 0, 'I found the dashboard to be reliable\n'),
#  Text(0, 0, 'I found the dashboard useful for completing the task\n'),
#  Text(0, 0, 'The displayed remaining distance agreed with the distance I could drive\n'),
#  Text(0, 0, 'I felt I understood what affected the remaining distance displayed by the dashboard\n'),
#  Text(0, 0, 'I felt I could influence the displayed remaining distance\n'),
#  Text(0, 0, 'The dashboard was difficult to understand\n'),
#  Text(0, 0, 'I felt the dashboard lacked information for completing the task\n')]

# %%
# Plot the data in a bar chart diagram

fig, ax = plt.subplots(figsize=(15,10))

labels = questions_guess.index
guess_mean = questions_guess["mean"].values
guess_std = questions_guess["std"].values

labels = questions_guess.index
diff_mean = questions_diff["mean"].values
diff_std = questions_diff["std"].values

x = np.arange(len(labels))
width = 0.4
capsize = 3

ax.barh( x - width/2, guess_mean, width, xerr=guess_std, capsize=capsize, label="Guess-o-meter", color=color_guess)
ax.barh( x + width/2, diff_mean, width, xerr=diff_std , capsize=capsize, label="Diff+COPE1", color=color_diff)

ax.set_xlabel("Mean score [0=Not at all, 7=Extremely]")
ax.set_title("Questionnaire mean score for both EVIS")

ax.set_xlim(0,7)
ax.grid(True)
ax.legend()
ax.set_yticks(x);
ax.set_yticklabels(labels);

# %%
fig.savefig("../figures-local/questionnaire_mean_score.png", dpi=300)
